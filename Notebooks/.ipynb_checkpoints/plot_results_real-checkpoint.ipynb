# %%
import numpy as np
import os
import cv2
import sys
import random
import argparse
import cvxpy as cvx
import matplotlib.pyplot as plt
import timeit
import seaborn as sns

from IPython.display import set_matplotlib_formats
from sklearn.decomposition import PCA
from skimage.color import rgb2gray

parentdir = os.path.dirname(os.getcwd())
sys.path.insert(0,parentdir)
from src_algorithm import src_algorithm
import prep_data

font_small = {'fontsize': 8}
font_large = {'fontsize': 10}
set_matplotlib_formats('pdf', 'svg', 'png')

# %matplotlib notebook
# %matplotlib inline

path = os.path.join(parentdir, 'Figures')

print(path)
# Out:
# /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/Figures

# %%
### Plot src scale with input size ###
train_path = os.path.join(parentdir, 'train') + os.sep
test_path = os.path.join(parentdir, 'test') + os.sep
    
shape = (7,7)
n_features = 40

### Feature selection option ###
#options = {'feature_selection': 'downsampling', 'dims': shape} # feature selection can be wither pca (eigenfaces) or downsampling
options = {'feature_selection': 'pca', 'dims': 40}
#options = {'feature_selection': 'random', 'dims': n_features}

TrainSet, TestSet = prep_data.prep_train_test(train_path, test_path, options)

print(TrainSet['X'].shape, TestSet['X'].shape)

### Parameters for src algorithm ###
sigma = 0.001
threshold = 0.5

print(f"Running SRC classifier with threshold: {threshold}, and feature selection: {options['feature_selection']}")

rec_rate, results = src_algorithm(TrainSet, TestSet, sigma, threshold)
# Out:
# (40, 594) (40, 54)
# Running SRC classifier with threshold: 0.5, and feature selection: pca
# SCI score:  0.6996523900151563
# RECOGNIZED AS:  obj1 TRUE:  obj1
# SCI score:  0.992900861716126
# RECOGNIZED AS:  obj1 TRUE:  obj1
# SCI score:  0.8936928567118855
# RECOGNIZED AS:  obj1 TRUE:  obj1
# SCI score:  0.9091902905877325
# RECOGNIZED AS:  obj1 TRUE:  obj1
# SCI score:  0.617474940596931
# RECOGNIZED AS:  obj1 TRUE:  obj1
# SCI score:  0.9794365910390688
# RECOGNIZED AS:  obj1 TRUE:  obj1
# SCI score:  0.48023113040945953
# RECOGNIZED AS:  None TRUE:  obj1
# SCI score:  0.9843814607428902
# RECOGNIZED AS:  obj1 TRUE:  obj1
# SCI score:  0.9414736229406391
# RECOGNIZED AS:  obj1 TRUE:  obj1
# SCI score:  0.9245869139251047
# RECOGNIZED AS:  obj6 TRUE:  obj6
# SCI score:  0.8973381574193816
# RECOGNIZED AS:  obj6 TRUE:  obj6
# SCI score:  0.8510914883210052
# RECOGNIZED AS:  obj6 TRUE:  obj6
# SCI score:  0.8794357236570773
# RECOGNIZED AS:  obj6 TRUE:  obj6
# SCI score:  0.6033018280476622
# RECOGNIZED AS:  obj6 TRUE:  obj6
# SCI score:  0.9449948498372853
# RECOGNIZED AS:  obj6 TRUE:  obj6
# SCI score:  0.9283947057604014
# RECOGNIZED AS:  obj6 TRUE:  obj6
# SCI score:  0.651057514802211
# RECOGNIZED AS:  obj6 TRUE:  obj6
# SCI score:  0.903260953574945
# RECOGNIZED AS:  obj6 TRUE:  obj6
# SCI score:  0.9243145120069032
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.7431542303696453
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.9822335430425063
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.9134467544466718
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.9397049736215346
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.6814478408994136
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.8678919440064577
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.9989132091236856
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.8656013257468862
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.9781742275836287
# RECOGNIZED AS:  obj2 TRUE:  obj2
# SCI score:  0.9750819280480097
# RECOGNIZED AS:  obj2 TRUE:  obj2
# SCI score:  0.9524162038632331
# RECOGNIZED AS:  obj2 TRUE:  obj2
# SCI score:  0.8502005945222484
# RECOGNIZED AS:  obj2 TRUE:  obj2
# SCI score:  0.9793633445108763
# RECOGNIZED AS:  obj2 TRUE:  obj2
# SCI score:  0.9860810347758082
# RECOGNIZED AS:  obj2 TRUE:  obj2
# SCI score:  0.9749909879170323
# RECOGNIZED AS:  obj2 TRUE:  obj2
# SCI score:  0.9968772453952987
# RECOGNIZED AS:  obj2 TRUE:  obj2
# SCI score:  0.9848706641872775
# RECOGNIZED AS:  obj2 TRUE:  obj2
# SCI score:  0.7654722953894775
# RECOGNIZED AS:  obj3 TRUE:  obj3
# SCI score:  0.8342627821502326
# RECOGNIZED AS:  obj3 TRUE:  obj3
# SCI score:  0.9156066928659785
# RECOGNIZED AS:  obj3 TRUE:  obj3
# SCI score:  0.8887755856517237
# RECOGNIZED AS:  obj3 TRUE:  obj3
# SCI score:  0.8522692831957182
# RECOGNIZED AS:  obj3 TRUE:  obj3
# SCI score:  0.7799506801938682
# RECOGNIZED AS:  obj3 TRUE:  obj3
# SCI score:  0.8802321161448404
# RECOGNIZED AS:  obj3 TRUE:  obj3
# SCI score:  0.8491753675433804
# RECOGNIZED AS:  obj3 TRUE:  obj3
# SCI score:  0.7970093563095414
# RECOGNIZED AS:  obj3 TRUE:  obj3
# SCI score:  0.9709031802959209
# RECOGNIZED AS:  obj4 TRUE:  obj4
# SCI score:  0.7053316871830957
# RECOGNIZED AS:  obj6 TRUE:  obj4
# SCI score:  0.974395006036892
# RECOGNIZED AS:  obj4 TRUE:  obj4
# SCI score:  0.9625473967465565
# RECOGNIZED AS:  obj4 TRUE:  obj4
# SCI score:  0.9182857312116612
# RECOGNIZED AS:  obj4 TRUE:  obj4
# SCI score:  0.9870214680373219
# RECOGNIZED AS:  obj4 TRUE:  obj4
# SCI score:  0.945239085602816
# RECOGNIZED AS:  obj4 TRUE:  obj4
# SCI score:  0.9632143162407983
# RECOGNIZED AS:  obj4 TRUE:  obj4
# SCI score:  0.8053980294511437
# RECOGNIZED AS:  obj4 TRUE:  obj4
# Predicted correctly: 52 out of 54 with recognition rate: 96.29629629629629 %

# %% [markdown]
# ## Plot coefficients

# %%
path = os.path.join(parentdir, 'Figures')

x = np.arange(len(results['coeff_vecs'][0]))
num_predicted = len(results['coeff_vecs'])

for i in range(num_predicted):
    label = TestSet['y'][i]
    predicted = results['pred'][i]
    file = TestSet['files'][i]
    print(f"### Plot for {label} number {i}, filename: {file} ###")
    sci_score = round(results['sci_scores'][i], 3)
    plt.figure(figsize=(5,3))
    plt.title(f'True label: {label}, Predicted: {predicted}, SCI-score: {sci_score}', fontdict=font_large)
    #label = f"SCI score: {results['sci_scores'][i]}"
    markerline, stemlines, baseline = plt.stem(x, results['coeff_vecs'][i])
    plt.setp(stemlines, 'linewidth', 0.7)
    plt.setp(markerline, markersize = 2.5)
    plt.setp(markerline, 'linewidth', 1)
    plt.xticks(fontsize=7)
    plt.yticks(fontsize=7)
    plt.xlabel('Vector elements', fontdict=font_large)
    plt.ylabel('Coefficients', fontdict=font_large)
    #label = f"SCI score: {results['sci_scores'][i]}"
    #plt.set_label([label])
    #plt.legend()
    #plt.savefig(os.path.join(path, f'coeffs_pca_{label}_{i}.png'))
# Out:
# ### Plot for obj1 number 0, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj1/89.jpg ###
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   from ipykernel import kernelapp as app
# ### Plot for obj1 number 1, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj1/28.jpg ###
# ### Plot for obj1 number 2, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj1/103.jpg ###
# ### Plot for obj1 number 3, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj1/107.jpg ###
# ### Plot for obj1 number 4, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj1/95.jpg ###
# ### Plot for obj1 number 5, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj1/82.jpg ###
# ### Plot for obj1 number 6, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj1/68.jpg ###
# ### Plot for obj1 number 7, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj1/2.jpg ###
# ### Plot for obj1 number 8, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj1/91.jpg ###
# ### Plot for obj6 number 9, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj6/63.jpg ###
# ### Plot for obj6 number 10, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj6/74.jpg ###
# ### Plot for obj6 number 11, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj6/75.jpg ###
# ### Plot for obj6 number 12, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj6/8.jpg ###
# ### Plot for obj6 number 13, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj6/34.jpg ###
# ### Plot for obj6 number 14, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj6/36.jpg ###
# ### Plot for obj6 number 15, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj6/19.jpg ###
# ### Plot for obj6 number 16, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj6/57.jpg ###
# ### Plot for obj6 number 17, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj6/54.jpg ###
# ### Plot for obj5 number 18, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj5/89.jpg ###
# ### Plot for obj5 number 19, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj5/61.jpg ###
# ### Plot for obj5 number 20, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj5/98.jpg ###
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   if sys.path[0] == '':
# ### Plot for obj5 number 21, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj5/15.jpg ###
# ### Plot for obj5 number 22, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj5/108.jpg ###
# ### Plot for obj5 number 23, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj5/33.jpg ###
# ### Plot for obj5 number 24, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj5/80.jpg ###
# ### Plot for obj5 number 25, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj5/82.jpg ###
# ### Plot for obj5 number 26, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj5/44.jpg ###
# ### Plot for obj2 number 27, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj2/89.jpg ###
# ### Plot for obj2 number 28, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj2/48.jpg ###
# ### Plot for obj2 number 29, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj2/102.jpg ###
# ### Plot for obj2 number 30, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj2/106.jpg ###
# ### Plot for obj2 number 31, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj2/22.jpg ###
# ### Plot for obj2 number 32, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj2/81.jpg ###
# ### Plot for obj2 number 33, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj2/41.jpg ###
# ### Plot for obj2 number 34, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj2/87.jpg ###
# ### Plot for obj2 number 35, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj2/85.jpg ###
# ### Plot for obj3 number 36, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj3/59.jpg ###
# ### Plot for obj3 number 37, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj3/64.jpg ###
# ### Plot for obj3 number 38, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj3/12.jpg ###
# ### Plot for obj3 number 39, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj3/37.jpg ###
# ### Plot for obj3 number 40, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj3/57.jpg ###
# ### Plot for obj3 number 41, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj3/55.jpg ###
# ### Plot for obj3 number 42, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj3/40.jpg ###
# ### Plot for obj3 number 43, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj3/54.jpg ###
# ### Plot for obj3 number 44, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj3/50.jpg ###
# ### Plot for obj4 number 45, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj4/61.jpg ###
# ### Plot for obj4 number 46, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj4/70.jpg ###
# ### Plot for obj4 number 47, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj4/66.jpg ###
# ### Plot for obj4 number 48, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj4/102.jpg ###
# ### Plot for obj4 number 49, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj4/13.jpg ###
# ### Plot for obj4 number 50, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj4/11.jpg ###
# ### Plot for obj4 number 51, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj4/104.jpg ###
# ### Plot for obj4 number 52, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj4/25.jpg ###
# ### Plot for obj4 number 53, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj4/94.jpg ###

# %%
### Rec. Rate ###
fig = plt.figure(figsize=(5,3))
plt.plot(thresholds, rec_rate)
#plt.scatter(thresholds, fals, c='g')
plt.plot(thresholds, rec_rate, '-ok', color='black',
         markersize=7, linewidth=2,
         markerfacecolor='white')
plt.xlabel('Threshold', fontdict=font_small)
plt.ylabel('False Positives', fontdict=font_small)
plt.xticks(fontsize=7)
plt.yticks(fontsize=7)
#plt.grid()
plt.title('False Positives of T3 by Threshold value', fontdict=font_large)
plt.show()
fig.savefig(f'Figures/false_positives.svg')

# %% [markdown]
# ## Residuals

# %%
### Plot residuals PCA ###
i = 0

#palette = sns.color_palette("Set2")
#palette = sns.color_palette('deep')
#palette = sns.color_palette("Paired")
palette = sns.color_palette("hls", 8)
#palette = sns.color_palette("tab10")

num_preds = len(results['coeff_vecs'])
classes = np.unique(TrainSet['y'])

for i in range(num_preds):
    res_vec = results['residuals'][i]
    sci_score = results['sci_scores'][i]
    label = TestSet['y'][i]
    file = TestSet['files'][i]
    print(f"### Plot for {label} number {i}, filename: {file} ###")
    
    plt.figure(figsize=(5,3))
    #sns.set_palette("pastel")
    graph = sns.barplot(x=classes, y=res_vec, palette=palette)
    plt.xticks(fontsize=7)
    plt.yticks(fontsize=7)
    plt.ylabel('Resisual of each class', fontdict = font_small)
    plt.title(f'Feature selection=PCA, Threshold={threshold}', fontdict=font_large)
    graph.axhline(threshold, color='r', label='Threshold', lw=0.7)
    graph.axhline(sci_score, color='g', label='SCI-score', lw=0.7)
    
    plt.legend(bbox_to_anchor=(1, 1), loc=1, prop={"size":6})
    #plt.savefig(os.path.join(path, f'res_pca_{label}_{i}.png'))
# Out:
# ### Plot for obj1 number 0, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj1/5.png ###
# ### Plot for obj1 number 1, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj1/2.png ###
# ### Plot for obj1 number 2, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj1/3.png ###
# ### Plot for obj6 number 3, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj6/bt18.png ###
# ### Plot for obj6 number 4, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj6/bt5.png ###
# ### Plot for obj6 number 5, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj6/bt1.png ###
# ### Plot for obj5 number 6, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj5/10.png ###
# ### Plot for obj5 number 7, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj5/5.png ###
# ### Plot for obj5 number 8, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj5/2.png ###
# ### Plot for obj2 number 9, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj2/9.png ###
# ### Plot for obj2 number 10, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj2/7.png ###
# ### Plot for obj2 number 11, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj2/3.png ###
# ### Plot for obj3 number 12, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj3/11.png ###
# ### Plot for obj3 number 13, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj3/10.png ###
# ### Plot for obj3 number 14, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj3/1.png ###
# ### Plot for obj4 number 15, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj4/9.png ###
# ### Plot for obj4 number 16, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj4/11.png ###
# ### Plot for obj4 number 17, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test/obj4/5.png ###
