# %%
import numpy as np
import os
import cv2
import sys
import random
import argparse
import cvxpy as cvx
import matplotlib.pyplot as plt
import timeit
import seaborn as sns

from IPython.display import set_matplotlib_formats
from sklearn.decomposition import PCA
from skimage.color import rgb2gray

parentdir = os.path.dirname(os.getcwd())
sys.path.insert(0,parentdir)
from src_algorithm import src_algorithm
import prep_data

font_small = {'fontsize': 8}
font_large = {'fontsize': 10}
set_matplotlib_formats('pdf', 'svg', 'png')

# %matplotlib notebook
# %matplotlib inline

path = os.path.join(parentdir, 'Figures/ParaData')

print(path)
# Out:
# /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/Figures/ParaData

# %%
### Plot src scale with input size ###
train_path = os.path.join(parentdir, 'train2') + os.sep
test_path = os.path.join(parentdir, 'test2') + os.sep
    
shape = (7,7)
n_features = 40

### Feature selection option ###
#options = {'feature_selection': 'downsampling', 'dims': shape} # feature selection can be wither pca (eigenfaces) or downsampling
options = {'feature_selection': 'pca', 'dims': 40}
#options = {'feature_selection': 'random', 'dims': n_features}

TrainSet, TestSet = prep_data.prep_train_test(train_path, test_path, options)

print(TrainSet['X'].shape, TestSet['X'].shape)

### Parameters for src algorithm ###
sigma = 0.001
threshold = 0.5

print(f"Running SRC classifier with threshold: {threshold}, and feature selection: {options['feature_selection']}")

rec_rate, results = src_algorithm(TrainSet, TestSet, sigma, threshold)
# Out:
# (40, 132) (40, 32)
# Running SRC classifier with threshold: 0.5, and feature selection: pca
# SCI score:  0.9969489213244561
# RECOGNIZED AS:  obj1 TRUE:  obj1
# SCI score:  0.9950539145106365
# RECOGNIZED AS:  obj1 TRUE:  obj1
# SCI score:  0.9787744549730679
# RECOGNIZED AS:  obj1 TRUE:  obj1
# SCI score:  0.9955014737894701
# RECOGNIZED AS:  obj1 TRUE:  obj1
# SCI score:  0.9404559631424556
# RECOGNIZED AS:  obj6 TRUE:  obj6
# SCI score:  0.969294856528338
# RECOGNIZED AS:  obj6 TRUE:  obj6
# SCI score:  0.9458641484943264
# RECOGNIZED AS:  obj6 TRUE:  obj6
# SCI score:  0.9791307127235657
# RECOGNIZED AS:  obj6 TRUE:  obj6
# SCI score:  1.0000000000000002
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.9818530378478778
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  1.0
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  1.0
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  1.0
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.7351723755454815
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.9781822501790431
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.9999999999999998
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  1.0000000000000002
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  1.0000000000000002
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.981727706846917
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  1.0000000000000002
# RECOGNIZED AS:  obj5 TRUE:  obj5
# SCI score:  0.9923678705040881
# RECOGNIZED AS:  obj2 TRUE:  obj2
# SCI score:  0.9981826755128045
# RECOGNIZED AS:  obj2 TRUE:  obj2
# SCI score:  0.9808727710191549
# RECOGNIZED AS:  obj2 TRUE:  obj2
# SCI score:  0.989271838081382
# RECOGNIZED AS:  obj2 TRUE:  obj2
# SCI score:  0.9621502067978394
# RECOGNIZED AS:  obj3 TRUE:  obj3
# SCI score:  0.9624110679867011
# RECOGNIZED AS:  obj3 TRUE:  obj3
# SCI score:  0.9398857372148584
# RECOGNIZED AS:  obj3 TRUE:  obj3
# SCI score:  0.9922790708822193
# RECOGNIZED AS:  obj3 TRUE:  obj3
# SCI score:  0.9390233304217073
# RECOGNIZED AS:  obj4 TRUE:  obj4
# SCI score:  0.824064658203682
# RECOGNIZED AS:  obj4 TRUE:  obj4
# SCI score:  0.9350701765785138
# RECOGNIZED AS:  obj4 TRUE:  obj4
# SCI score:  0.990665480647601
# RECOGNIZED AS:  obj4 TRUE:  obj4
# Predicted correctly: 32 out of 32 with recognition rate: 100.0 %

# %% [markdown]
# ## Plot coefficients

# %%
x = np.arange(len(results['coeff_vecs'][0]))
num_predicted = len(results['coeff_vecs'])

for i in range(num_predicted):
    label = TestSet['y'][i]
    predicted = results['pred'][i]
    file = TestSet['files'][i]
    print(f"### Plot for {label} number {i}, filename: {file} ###")
    sci_score = round(results['sci_scores'][i], 3)
    plt.figure(figsize=(5,3))
    plt.title(f'SCI-score: {sci_score}', fontdict=font_large)
    #label = f"SCI score: {results['sci_scores'][i]}"
    markerline, stemlines, baseline = plt.stem(x, results['coeff_vecs'][i])
    plt.setp(stemlines, 'linewidth', 0.7)
    plt.setp(markerline, markersize = 2.5)
    plt.setp(markerline, 'linewidth', 1)
    plt.xticks(fontsize=7)
    plt.yticks(fontsize=7)
    plt.xlabel('Vector elements', fontdict=font_large)
    plt.ylabel('Coefficients', fontdict=font_large)
    #label = f"SCI score: {results['sci_scores'][i]}"
    #plt.set_label([label])
    #plt.legend()
    plt.savefig(os.path.join(path, f'coeffs_{label}_{i}.png'))
# Out:
# ### Plot for obj1 number 0, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj1/8.jpg ###
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   del sys.path[0]
# ### Plot for obj1 number 1, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj1/10.jpg ###
# ### Plot for obj1 number 2, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj1/25.jpg ###
# ### Plot for obj1 number 3, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj1/7.jpg ###
# ### Plot for obj6 number 4, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj6/19 12.26.33.jpg ###
# ### Plot for obj6 number 5, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj6/13.jpg ###
# ### Plot for obj6 number 6, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj6/5.jpg ###
# ### Plot for obj6 number 7, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj6/2 12.26.33.jpg ###
# ### Plot for obj5 number 8, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/8.jpg ###
# ### Plot for obj5 number 9, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/9.jpg ###
# ### Plot for obj5 number 10, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/15.jpg ###
# ### Plot for obj5 number 11, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/17.jpg ###
# ### Plot for obj5 number 12, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/13.jpg ###
# ### Plot for obj5 number 13, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/23.jpg ###
# ### Plot for obj5 number 14, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/26.jpg ###
# ### Plot for obj5 number 15, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/18.jpg ###
# ### Plot for obj5 number 16, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/4.jpg ###
# ### Plot for obj5 number 17, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/6.jpg ###
# ### Plot for obj5 number 18, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/2.jpg ###
# ### Plot for obj5 number 19, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/3.jpg ###
# ### Plot for obj2 number 20, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj2/8.jpg ###
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   # Remove the CWD from sys.path while we load stuff.
# ### Plot for obj2 number 21, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj2/14.jpg ###
# ### Plot for obj2 number 22, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj2/17.jpg ###
# ### Plot for obj2 number 23, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj2/24.jpg ###
# ### Plot for obj3 number 24, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj3/8.jpg ###
# ### Plot for obj3 number 25, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj3/15.jpg ###
# ### Plot for obj3 number 26, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj3/13.jpg ###
# ### Plot for obj3 number 27, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj3/24.jpg ###
# ### Plot for obj4 number 28, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj4/16.jpg ###
# ### Plot for obj4 number 29, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj4/23.jpg ###
# ### Plot for obj4 number 30, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj4/25.jpg ###
# ### Plot for obj4 number 31, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj4/5.jpg ###

# %%
### Rec. Rate ###
fig = plt.figure(figsize=(5,3))
plt.plot(thresholds, rec_rate)
#plt.scatter(thresholds, fals, c='g')
plt.plot(thresholds, rec_rate, '-ok', color='black',
         markersize=7, linewidth=2,
         markerfacecolor='white')
plt.xlabel('Threshold', fontdict=font_small)
plt.ylabel('False Positives', fontdict=font_small)
plt.xticks(fontsize=7)
plt.yticks(fontsize=7)
#plt.grid()
plt.title('False Positives of T3 by Threshold value', fontdict=font_large)
plt.show()
fig.savefig(f'Figures/false_positives.svg')

# %% [markdown]
# ## Residuals

# %%
### Plot residuals PCA ###
i = 0

#palette = sns.color_palette("Set2")
#palette = sns.color_palette('deep')
#palette = sns.color_palette("Paired")
palette = sns.color_palette("hls", 8)
#palette = sns.color_palette("tab10")

num_preds = len(results['coeff_vecs'])
classes = np.unique(TrainSet['y'])

for i in range(num_preds):
    res_vec = results['residuals'][i]
    sci_score = round(results['sci_scores'][i],2)
    label = TestSet['y'][i]
    predicted = results['pred'][i]
    file = TestSet['files'][i]
    print(f"### Plot for {label} number {i}, filename: {file} ###")
    
    plt.figure(figsize=(5,3))
    #sns.set_palette("pastel")
    graph = sns.barplot(x=classes, y=res_vec, palette=palette)
    plt.xticks(fontsize=7)
    plt.yticks(fontsize=7)
    plt.ylabel('Resisual', fontdict = font_small)
    plt.title(f'True label: {label}, Predicted: {predicted}', fontdict=font_large)
    graph.axhline(threshold, color='r', label=f'Threshold = {threshold}', lw=0.7)
    graph.axhline(sci_score, color='g', label=f'SCI-score = {sci_score}', lw=0.7)
    
    plt.legend(bbox_to_anchor=(1, 1), loc=1, prop={"size":6})
    plt.savefig(os.path.join(path, f'res_{label}_{i}.png'))
# Out:
# ### Plot for obj1 number 0, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj1/8.jpg ###
# ### Plot for obj1 number 1, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj1/10.jpg ###
# ### Plot for obj1 number 2, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj1/25.jpg ###
# ### Plot for obj1 number 3, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj1/7.jpg ###
# ### Plot for obj6 number 4, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj6/19 12.26.33.jpg ###
# ### Plot for obj6 number 5, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj6/13.jpg ###
# ### Plot for obj6 number 6, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj6/5.jpg ###
# ### Plot for obj6 number 7, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj6/2 12.26.33.jpg ###
# ### Plot for obj5 number 8, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/8.jpg ###
# ### Plot for obj5 number 9, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/9.jpg ###
# ### Plot for obj5 number 10, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/15.jpg ###
# ### Plot for obj5 number 11, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/17.jpg ###
# ### Plot for obj5 number 12, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/13.jpg ###
# ### Plot for obj5 number 13, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/23.jpg ###
# ### Plot for obj5 number 14, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/26.jpg ###
# ### Plot for obj5 number 15, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/18.jpg ###
# ### Plot for obj5 number 16, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/4.jpg ###
# ### Plot for obj5 number 17, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/6.jpg ###
# ### Plot for obj5 number 18, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/2.jpg ###
# ### Plot for obj5 number 19, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj5/3.jpg ###
# ### Plot for obj2 number 20, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj2/8.jpg ###
# ### Plot for obj2 number 21, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj2/14.jpg ###
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ### Plot for obj2 number 22, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj2/17.jpg ###
# ### Plot for obj2 number 23, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj2/24.jpg ###
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ### Plot for obj3 number 24, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj3/8.jpg ###
# ### Plot for obj3 number 25, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj3/15.jpg ###
# ### Plot for obj3 number 26, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj3/13.jpg ###
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ### Plot for obj3 number 27, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj3/24.jpg ###
# ### Plot for obj4 number 28, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj4/16.jpg ###
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ### Plot for obj4 number 29, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj4/23.jpg ###
# ### Plot for obj4 number 30, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj4/25.jpg ###
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ### Plot for obj4 number 31, filename: /Users/juliagraham/IT/MasterThesis2021/dmd-and-cs-for-3D-object-detection/test2/obj4/5.jpg ###
